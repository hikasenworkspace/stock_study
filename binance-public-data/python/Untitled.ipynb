# %%
import utility as utl
from utility import *
from importlib import reload
reload(utl)
def download_daily_trades(trading_type, symbols, num_symbols, dates, start_date, end_date, folder, checksum):
    current = 0
    date_range = None

    if start_date and end_date:
        date_range = start_date + " " + end_date

    if not start_date:
        start_date = START_DATE
    else:
        start_date = convert_to_date_object(start_date)

    if not end_date:
        end_date = END_DATE
    else:
        end_date = convert_to_date_object(end_date)
        
    print("Found {} symbols".format(num_symbols))

    for symbol in symbols:
        print("[{}/{}] - start download daily {} trades ".format(current+1, num_symbols, symbol))
        for date in dates:
            current_date = convert_to_date_object(date)
            if current_date >= start_date and current_date <= end_date:
                path = get_path(trading_type, "trades", "daily", symbol)
                file_name = "{}-trades-{}.zip".format(symbol.upper(), date)
                print(file_name)
                print(path)
                download_file(path, file_name, date_range, folder)

                if checksum == 1:
                    checksum_path = get_path(trading_type, "trades", "daily", symbol)
                    checksum_file_name = "{}-trades-{}.zip.CHECKSUM".format(symbol.upper(), date)
                    download_file(checksum_path, checksum_file_name, date_range, folder)

        current += 1
        

YEARS = ['2017', '2018', '2019', '2020', '2021', '2022']
INTERVALS = ["1m", "5m", "15m", "30m", "1h", "2h", "4h", "6h", "8h", "12h", "1d", "3d", "1w", "1mo"]
DAILY_INTERVALS = ["1m", "5m", "15m", "30m", "1h", "2h", "4h", "6h", "8h", "12h", "1d"]
TRADING_TYPE = ["spot", "um", "cm"]
MONTHS = list(range(1,13))
MAX_DAYS = 35
BASE_URL = 'https://data.binance.vision/'
START_DATE = date(int(YEARS[0]), MONTHS[0], 1)
END_DATE = datetime.date(datetime.now())
EXTRACT = [True, False]

# %%
class historical_trade:
    def __init__(self, trading_type, symbols)

# %%
import sys
from datetime import *
import pandas as pd

dates = pd.date_range(end = datetime.today(), periods = MAX_DAYS).to_pydatetime().tolist()
dates = [date.strftime("%Y-%m-%d") for date in dates][:2]

# %%
type(dates[0]) == str
# Out:
# True

# %%
download_daily_trades("spot",["ETHBTC"],1, dates, None, None, None, 0)
# Out:
# Found 1 symbols
# [1/1] - start download daily ETHBTC trades
# ETHBTC-trades-2022-02-27.zip
# data/spot/daily/trades/ETHBTC/
#
# file already exists! /home/user/stock_study/binance-public-data/python/data/spot/daily/trades/ETHBTC/ETHBTC-trades-2022-02-27.zip
# ETHBTC-trades-2022-02-28.zip
# data/spot/daily/trades/ETHBTC/
#
# file already exists! /home/user/stock_study/binance-public-data/python/data/spot/daily/trades/ETHBTC/ETHBTC-trades-2022-02-28.zip

# %%
set(["ETHBTC", "LTCBTC"]) <= set(get_all_symbols("spot"))
# Out:
# True

# %%
# Out:
# {'RVNBUSD',
#  'GRSETH',
#  'RENBUSD',
#  'ANTBNB',
#  'ARBNB',
#  'USDCUSDT',
#  'MBOXBTC',
#  'ASTETH',
#  'TKOUSDT',
#  'TVKBTC',
#  'VETBUSD',
#  'RUNEGBP',
#  'AUDIOUSDT',
#  'BCPTTUSD',
#  'CLOAKBTC',
#  'DCRUSDT',
#  'BNBTUSD',
#  'BCHSVBTC',
#  'KAVAETH',
#  'BNBUSDS',
#  'DOGEBIDR',
#  'ROSEUSDT',
#  'LRCBTC',
#  'WINGBNB',
#  'SALTBTC',
#  'FISBTC',
#  'POEETH',
#  'LINKEUR',
#  'BNBBKRW',
#  'WAVESRUB',
#  'TRBBNB',
#  'CHZEUR',
#  'RENUSDT',
#  'DASHUSDT',
#  'MCOBNB',
#  'RVNBTC',
#  'GXSUSDT',
#  'BNBETH',
#  'GRTBUSD',
#  'ADAGBP',
#  'SHIBDOGE',
#  'BUSDUSDT',
#  'BCHBNB',
#  'PYRUSDT',
#  'NEBLBTC',
#  'XTZUPUSDT',
#  'ONGBTC',
#  'CVXUSDT',
#  'KEYETH',
#  'IRISBNB',
#  'BCPTBTC',
#  'FTMBRL',
#  'BRDBNB',
#  'SOLAUD',
#  'NURUB',
#  'ASTRUSDT',
#  'DGBUSDT',
#  'ATOMUSDC',
#  'ZECTUSD',
#  'BNBUSDC',
#  'CAKEBNB',
#  'XRPBTC',
#  'PPTETH',
#  'GXSBNB',
#  'BNBBRL',
#  'QTUMUSDT',
#  'QKCBTC',
#  'ALPACABNB',
#  'OMGETH',
#  'FLMBNB',
#  'POWRBNB',
#  'SANDUSDT',
#  'DYDXBUSD',
#  'ARKETH',
#  'DUSKBNB',
#  'ENGBTC',
#  'ZILBNB',
#  'VITEBNB',
#  'LTCNGN',
#  'ICNBTC',
#  'COMPBTC',
#  'COMPBUSD',
#  'ONTPAX',
#  'ETHBRL',
#  'BALBUSD',
#  'POLSBNB',
#  'ETCBUSD',
#  'SUNBUSD',
#  'DIABUSD',
#  'YFIIBNB',
#  'DEGOBTC',
#  'FARMBTC',
#  'ETHUPUSDT',
#  'ADABNB',
#  'MANATRY',
#  'RADBNB',
#  'XTZBTC',
#  'APPCBTC',
#  'POLYBNB',
#  'BCHDOWNUSDT',
#  'TRBBTC',
#  'NAVETH',
#  'XLMBNB',
#  'QLCBNB',
#  'USDTNGN',
#  'CKBBUSD',
#  'DENTBTC',
#  'ALCXBTC',
#  'FISBIDR',
#  'FORTHBTC',
#  'MFTETH',
#  'XRPBNB',
#  'ENJBNB',
#  'GRTTRY',
#  'RIFBTC',
#  'ETHPAX',
#  'RSRBTC',
#  'THETABUSD',
#  'IOTAETH',
#  'ONEPAX',
#  'HOTBNB',
#  'FETBTC',
#  'SUSHIBNB',
#  'AVABNB',
#  'COTIUSDT',
#  'UNIDOWNUSDT',
#  'FXSBTC',
#  'ORNUSDT',
#  'CRVUSDT',
#  'NCASHETH',
#  'GLMRUSDT',
#  'LENDBTC',
#  'STEEMBNB',
#  'PSGBTC',
#  'BCPTPAX',
#  'LENDBKRW',
#  'AGLDBNB',
#  'EOSETH',
#  'C98BNB',
#  'ZECBTC',
#  'WRXEUR',
#  'MLNUSDT',
#  'FUNBTC',
#  'RENBNB',
#  'ASRBTC',
#  'FTMUSDT',
#  'OMGBUSD',
#  'HOTEUR',
#  'ETHBEARUSDT',
#  'USDTIDRT',
#  'MDTUSDT',
#  'ONETRY',
#  'BTCTRY',
#  'LUNAAUD',
#  'WINBTC',
#  'BNTUSDT',
#  'SHIBBUSD',
#  'SNTBTC',
#  'BUSDNGN',
#  'SNMBTC',
#  'SOLBUSD',
#  'PNTBTC',
#  'GLMRBUSD',
#  'BTGBUSD',
#  'YFIBUSD',
#  'ENSBUSD',
#  'ANTUSDT',
#  'SUBBTC',
#  'EGLDBNB',
#  'STMXETH',
#  'DOTBKRW',
#  'WINGSETH',
#  'BUSDRUB',
#  'XRPRUB',
#  'RUNEBUSD',
#  'ACHBTC',
#  '1INCHUPUSDT',
#  'BCHBUSD',
#  'ZECUSDT',
#  'AGLDBTC',
#  'JASMYBUSD',
#  'FISBRL',
#  'POLYUSDT',
#  'FTMBIDR',
#  'DODOBTC',
#  'CTKUSDT',
#  'MCUSDT',
#  'AVAXUSDT',
#  'SOLGBP',
#  'RUNEETH',
#  'ADABKRW',
#  'XZCETH',
#  'CELOBTC',
#  'NCASHBTC',
#  'ACMUSDT',
#  'BLZETH',
#  'OSTBNB',
#  'AXSBRL',
#  'ILVBTC',
#  'PLABTC',
#  'JOEUSDT',
#  'DAIBNB',
#  'SNXBNB',
#  'ADAAUD',
#  'ALGOBIDR',
#  'GMTBTC',
#  'SPELLBNB',
#  'UNIBUSD',
#  'MCBTC',
#  'QUICKBUSD',
#  'XLMEUR',
#  'UNIEUR',
#  'BSWUSDT',
#  'QLCBTC',
#  'TRIBEBTC',
#  'ORNBUSD',
#  'STORJUSDT',
#  'GMTETH',
#  'TRXBUSD',
#  'ASTBTC',
#  'JOEBTC',
#  'DLTBNB',
#  'CHZBTC',
#  'NULSBTC',
#  'CVXBUSD',
#  'ETCBTC',
#  'DOTBNB',
#  'LTCBNB',
#  'CHZBUSD',
#  'ETHDOWNUSDT',
#  'LTCGBP',
#  'HNTBTC',
#  'WINUSDC',
#  'HSRETH',
#  'HNTBUSD',
#  'ADARUB',
#  'RGTUSDT',
#  'BTGBTC',
#  'ETHTRY',
#  'SOLBIDR',
#  'BTCBUSD',
#  'NAVBNB',
#  'ADXBNB',
#  'FORUSDT',
#  'WRXBUSD',
#  'HARDBTC',
#  'IRISBUSD',
#  'RAMPUSDT',
#  'USDCPAX',
#  'CHRBTC',
#  'LSKETH',
#  'KEYUSDT',
#  'ETHAUD',
#  'BZRXUSDT',
#  'PSGUSDT',
#  'POWRBUSD',
#  'ERDBUSD',
#  'OAXBTC',
#  'ATABNB',
#  'HEGICBUSD',
#  'QSPBTC',
#  'ETHBUSD',
#  'ETCBNB',
#  'INSETH',
#  'WPRETH',
#  'MOVRBUSD',
#  'DOTETH',
#  'TBUSD',
#  'TNTBTC',
#  'AUCTIONBTC',
#  'ALICEBIDR',
#  'KEEPBNB',
#  'BTCBRL',
#  'PHBBTC',
#  'INJBTC',
#  'API3USDT',
#  'OGUSDT',
#  'CMTBTC',
#  'DCRBNB',
#  'DOTTRY',
#  'QNTBTC',
#  'ALPACABUSD',
#  'SCRTUSDT',
#  'BTTCUSDT',
#  'SXPUSDT',
#  'ATAUSDT',
#  'PPTBTC',
#  'HOTBTC',
#  'XLMBUSD',
#  'CVPETH',
#  'CELRBTC',
#  'CVPBUSD',
#  'VITEBTC',
#  'IOSTBTC',
#  'ARPAUSDT',
#  'ICPBUSD',
#  'VIABNB',
#  'OCEANUSDT',
#  'JASMYTRY',
#  'MFTBTC',
#  'LENDUSDT',
#  'XLMDOWNUSDT',
#  'RAREBUSD',
#  'QTUMBUSD',
#  'BTSBUSD',
#  'AMPUSDT',
#  'KDABUSD',
#  'GALABRL',
#  'YOYOBTC',
#  'BTCGBP',
#  'FLOWUSDT',
#  'BCDBTC',
#  'NUBTC',
#  'RDNBTC',
#  'DYDXETH',
#  'YFIDOWNUSDT',
#  'OAXETH',
#  'KAVABNB',
#  'GRSBTC',
#  'ONEETH',
#  'SHIBBRL',
#  'EVXETH',
#  'HBARUSDT',
#  'ETHUSDC',
#  'LTCTUSD',
#  'SXPDOWNUSDT',
#  'XNOBTC',
#  'ANKRBNB',
#  'JOEBUSD',
#  'ALCXUSDT',
#  'CHRBUSD',
#  'LUNAETH',
#  'XRPBEARUSDT',
#  'PHBPAX',
#  'SXPEUR',
#  'SCRTBUSD',
#  'BATPAX',
#  'LOKABNB',
#  'AAVEDOWNUSDT',
#  'MITHUSDT',
#  'SANDBIDR',
#  'SSVBTC',
#  'BZRXBUSD',
#  'STPTBUSD',
#  'ICPEUR',
#  'PONDBTC',
#  'DOTBTC',
#  'SKLUSDT',
#  'AXSBTC',
#  'NPXSBTC',
#  'PROMBTC',
#  'ATOMBTC',
#  'XVGUSDT',
#  'ONEUSDT',
#  'XRPUPUSDT',
#  'DOGEBNB',
#  'CFXBTC',
#  'REQUSDT',
#  'SANTOSBTC',
#  'COCOSTRY',
#  'CFXBUSD',
#  'INSBTC',
#  'DREPBTC',
#  'SKYETH',
#  'LTCUPUSDT',
#  'CRVBNB',
#  'LTOBNB',
#  'BTGETH',
#  'DCRBTC',
#  'WINUSDT',
#  'ZILBUSD',
#  'ILVUSDT',
#  'ICNETH',
#  'NUAUD',
#  'IOSTUSDT',
#  'BTTCUSDC',
#  'ICPUSDT',
#  'BNBGBP',
#  'ICPBNB',
#  'DEXEBUSD',
#  'TORNBNB',
#  'GNTBNB',
#  'DOTBIDR',
#  'DOGEGBP',
#  'XVSBUSD',
#  'MBOXUSDT',
#  'SCRTETH',
#  'FARMBNB',
#  'SCETH',
#  'DREPBNB',
#  'VETEUR',
#  'SCUSDT',
#  'FRONTUSDT',
#  'AKROBTC',
#  'USDTBKRW',
#  'COMPUSDT',
#  'NEARUSDT',
#  'PHXETH',
#  'WBTCETH',
#  'UNIUSDT',
#  'CHZBRL',
#  'LOKABUSD',
#  'BETAETH',
#  'CNDBTC',
#  'LUNATRY',
#  'ALPHAUSDT',
#  'CKBBTC',
#  'EOSUPUSDT',
#  'SSVETH',
#  'ROSETRY',
#  'OGNUSDT',
#  'ALPHABUSD',
#  'ADXBTC',
#  'GNTBTC',
#  'BNBBIDR',
#  'TWTUSDT',
#  'TROYBTC',
#  'ETHBULLUSDT',
#  'PERLBTC',
#  'FTTBTC',
#  'BNBRUB',
#  'OCEANBTC',
#  'BNXBTC',
#  'MDXBUSD',
#  'FUNUSDT',
#  'STORMBTC',
#  'COCOSUSDT',
#  'ETHRUB',
#  'AAVEBUSD',
#  'VENUSDT',
#  'KNCUSDT',
#  'USDSBUSDT',
#  'QLCETH',
#  'HIGHBTC',
#  'RLCBTC',
#  'EZETH',
#  'GNOBNB',
#  'SANTOSBUSD',
#  'TKOBTC',
#  'ETHEUR',
#  'PHABTC',
#  'CAKEAUD',
#  'FTMBNB',
#  'NBTBIDR',
#  'VIDTBTC',
#  'ZENBUSD',
#  'HIGHBNB',
#  'LINKGBP',
#  'XMRUSDT',
#  'TRIBEUSDT',
#  'SHIBAUD',
#  'REPBTC',
#  'ETHBTC',
#  'POABTC',
#  'HSRBTC',
#  'WNXMBNB',
#  'YFIBNB',
#  'LTCRUB',
#  'AAVEBRL',
#  'SUSHIUSDT',
#  'LTOBTC',
#  'GOBNB',
#  'STXBTC',
#  'IDEXUSDT',
#  'CVCETH',
#  'ONTUSDC',
#  'DASHETH',
#  'IOTXBUSD',
#  'LITBUSD',
#  'YFIBTC',
#  'FLUXBTC',
#  'XTZTRY',
#  'BTTTRY',
#  'ATOMTUSD',
#  'RNDRUSDT',
#  'REEFBTC',
#  'MLNBTC',
#  'EOSBTC',
#  'BTTUSDC',
#  'SYSBUSD',
#  'APEEUR',
#  'TORNBTC',
#  'ETCPAX',
#  'FETUSDT',
#  'PUNDIXUSDT',
#  'ETHDAI',
#  'AUTOBTC',
#  'BCPTETH',
#  'AGLDBUSD',
#  'ONTBTC',
#  'NAVBTC',
#  'BCHABCTUSD',
#  'ETHUST',
#  'CVCBTC',
#  'KEEPBUSD',
#  'WRXUSDT',
#  'BTCDAI',
#  'KMDETH',
#  'ATOMUSDT',
#  'QSPBNB',
#  'UFTETH',
#  'EVXBTC',
#  'RLCUSDT',
#  'SANDTRY',
#  'ALPHABNB',
#  'ADAUSDC',
#  'FRONTETH',
#  'JASMYBNB',
#  'TKOBUSD',
#  'WAXPUSDT',
#  'GTCBUSD',
#  'NEARBTC',
#  'ICPTRY',
#  'OMGBTC',
#  'ACHUSDT',
#  'LINKBRL',
#  'MDTBUSD',
#  'GTOUSDT',
#  'XRPNGN',
#  'XTZBUSD',
#  'WNXMBUSD',
#  'FARMBUSD',
#  'SXPAUD',
#  'TRIGBTC',
#  'WAVESPAX',
#  'DYDXBNB',
#  'MBOXTRY',
#  'HIVEBNB',
#  'KP3RBUSD',
#  'WAVESUSDT',
#  'BELUSDT',
#  'SPELLTRY',
#  'DUSKUSDT',
#  'KP3RUSDT',
#  'TFUELUSDT',
#  'BLZUSDT',
#  'API3BUSD',
#  'CAKEBUSD',
#  'HIVEBUSD',
#  'MINAUSDT',
#  'OMBUSD',
#  'DARBTC',
#  'MIRBUSD',
#  'WAVESBNB',
#  'BULLUSDT',
#  'CLVBUSD',
#  'LINKTUSD',
#  'AEBTC',
#  'UMABUSD',
#  'AUDUSDC',
#  'YGGBNB',
#  'CTXCBUSD',
#  'EOSEUR',
#  'TUSDT',
#  'BCCETH',
#  'CAKEUSDT',
#  'CHZTRY',
#  'ELFBTC',
#  'NMRBTC',
#  'BELBNB',
#  'FIDABTC',
#  'OOKIUSDT',
#  'BNBEUR',
#  'NANOBNB',
#  'LINKUPUSDT',
#  'HOTBRL',
#  'GASBTC',
#  'HOTETH',
#  'DASHBTC',
#  'CLOAKETH',
#  'LOKABTC',
#  'STORMETH',
#  'RPXBTC',
#  'AAVEBTC',
#  'KLAYBNB',
#  'LPTUSDT',
#  'LINKBTC',
#  'VETBTC',
#  'SXPBUSD',
#  'CHESSBUSD',
#  'BCCUSDT',
#  'ADAUPUSDT',
#  'GTOPAX',
#  'PSGBUSD',
#  'MATICBNB',
#  'ONEBUSD',
#  'BTCUPUSDT',
#  'OCEANBNB',
#  'BQXETH',
#  'BNTETH',
#  'JUVBUSD',
#  'NANOBTC',
#  'FORTHBUSD',
#  'DOGEUSDC',
#  'CLVBNB',
#  'CHRUSDT',
#  'MBLUSDT',
#  'DOTRUB',
#  'SUSHIBTC',
#  'AEBNB',
#  'BANDBNB',
#  'ETHNGN',
#  'AEETH',
#  'NASBTC',
#  'BNBUPUSDT',
#  'JSTBNB',
#  'FTMRUB',
#  'SUNBTC',
#  'ZECETH',
#  'BAKEBNB',
#  'FILBUSD',
#  'XNOETH',
#  'EPSBUSD',
#  'STXUSDT',
#  'WOOUSDT',
#  'ALGOBUSD',
#  'LAZIOTRY',
#  'REPBUSD',
#  'NEOETH',
#  'BUSDBIDR',
#  'ADAUSDT',
#  'ANKRBUSD',
#  'YGGBTC',
#  'BTGUSDT',
#  'ZILBTC',
#  'OGNBNB',
#  'ETCETH',
#  'CITYBTC',
#  'MBOXBNB',
#  'MTLBTC',
#  'UTKBUSD',
#  'MDXBNB',
#  'XRPGBP',
#  'STRAXUSDT',
#  'XRPDOWNUSDT',
#  'MBLBTC',
#  'MATICETH',
#  'SANDAUD',
#  'CTSIBTC',
#  'FIDABNB',
#  'BUSDZAR',
#  'BTCRUB',
#  'LTOUSDT',
#  'LAZIOEUR',
#  'DUSKPAX',
#  'LITUSDT',
#  'KMDUSDT',
#  'LINABNB',
#  'VIBETH',
#  'OMGBNB',
#  'LTCUSDC',
#  'AAVEBKRW',
#  'EPSBTC',
#  'BNBBEARUSDT',
#  'AVAXAUD',
#  'ETCTUSD',
#  'THETAEUR',
#  'KAVABTC',
#  'WOOBTC',
#  'VTHOBUSD',
#  'GHSTBUSD',
#  'BCHABCUSDC',
#  'VIBEETH',
#  'EZBTC',
#  'KLAYBUSD',
#  'BUSDBKRW',
#  'BNTBUSD',
#  'AMPBNB',
#  'WINGBUSD',
#  'SLPBNB',
#  'REQBTC',
#  'TVKBUSD',
#  'ANKRTUSD',
#  'BEARBUSD',
#  'QUICKUSDT',
#  'USDTTRY',
#  'KDABTC',
#  'BDOTDOT',
#  'ACAUSDT',
#  'VOXELBTC',
#  'TCTBNB',
#  'SWRVBNB',
#  'LINABTC',
#  'ANYBTC',
#  'BCHABCPAX',
#  'TROYUSDT',
#  'AGIETH',
#  'ADAPAX',
#  'BETABTC',
#  'ROSEBUSD',
#  'STRATETH',
#  'CLVBTC',
#  'APEBNB',
#  'MCOUSDT',
#  'NANOETH',
#  'AVAXBTC',
#  'FLOWBTC',
#  'EGLDETH',
#  'COTIBTC',
#  'LUNABNB',
#  'MINABTC',
#  'PYRBTC',
#  'BTSUSDT',
#  'BNBBUSD',
#  'XEMBUSD',
#  'SUSHIBUSD',
#  'ANTBUSD',
#  'BCHABCBTC',
#  'GALABUSD',
#  'BEAMUSDT',
#  'NPXSETH',
#  'ATOMEUR',
#  'TOMOBUSD',
#  'AVAXGBP',
#  'GMTUSDT',
#  'ALGOPAX',
#  'C98BTC',
#  'LENDBUSD',
#  'AAVEETH',
#  'LITBTC',
#  'BCDETH',
#  'MANABUSD',
#  'XVSBNB',
#  'FLMBTC',
#  'RADBUSD',
#  'SCBUSD',
#  'QUICKBNB',
#  'BARUSDT',
#  'ETCUSDT',
#  'DAIBTC',
#  'STRAXBTC',
#  'IOTXETH',
#  'RSRUSDT',
#  'NEOTUSD',
#  'TRXXRP',
#  'PLABUSD',
#  'DREPUSDT',
#  'VOXELBUSD',
#  'NBSBTC',
#  'ILVBUSD',
#  'ARPATRY',
#  'NEOPAX',
#  'ETHUSDT',
#  'FIROBTC',
#  'TKOBIDR',
#  'AVAXBIDR',
#  'NXSBNB',
#  'WINGUSDT',
#  'HIVEBTC',
#  'ZECBNB',
#  'BALBNB',
#  'MCOETH',
#  'USTUSDT',
#  'FTMBUSD',
#  'CELRBUSD',
#  'SHIBEUR',
#  'LSKUSDT',
#  'LOKAUSDT',
#  'DOTBUSD',
#  'TWTBTC',
#  'ASRUSDT',
#  'FIROUSDT',
#  'LINAUSDT',
#  'CHZUSDT',
#  'BICOUSDT',
#  'MFTUSDT',
#  'ARKBTC',
#  'AVAXBUSD',
#  'ONTETH',
#  'ETHBKRW',
#  'DLTBTC',
#  'ERDUSDC',
#  'DUSKBUSD',
#  'FTTBUSD',
#  'ZENETH',
#  'MASKBNB',
#  'DFETH',
#  'ONTTRY',
#  'MTHBTC',
#  'BNBIDRT',
#  'FTMBTC',
#  'PHABUSD',
#  'PAXGBUSD',
#  'VGXBTC',
#  'GRTETH',
#  'TUSDUSDT',
#  'ARBTC',
#  'RDNETH',
#  'ANCBUSD',
#  'CRVBUSD',
#  'MKRBNB',
#  'CHRBNB',
#  'NULSETH',
#  'RPXETH',
#  'MODBTC',
#  'BUSDIDRT',
#  'ACMBTC',
#  'QTUMBNB',
#  'DOGEUSDT',
#  'GTOETH',
#  'BCHSVPAX',
#  'GXSBTC',
#  'GTCUSDT',
#  'NXSETH',
#  'DYDXBTC',
#  'ACABTC',
#  'MKRBTC',
#  'ETHZAR',
#  'LSKBUSD',
#  'TRXEUR',
#  'FIDABUSD',
#  'BNBUST',
#  'PROMBUSD',
#  'XRPTUSD',
#  'VETUSDT',
#  'FUNETH',
#  'PORTOTRY',
#  'COTIBNB',
#  'BLZBUSD',
#  'BATBNB',
#  'YFIIUSDT',
#  'BTCBIDR',
#  'PORTOEUR',
#  'DAIUSDT',
#  'ERNBNB',
#  'OMBTC',
#  'ZILETH',
#  'FTMTUSD',
#  'LSKBNB',
#  'NUUSDT',
#  'PIVXBTC',
#  'WBTCBTC',
#  'SANDBRL',
#  'FXSUSDT',
#  'XRPAUD',
#  'LINKETH',
#  'QNTBUSD',
#  'TFUELUSDC',
#  'ONEBIDR',
#  'DARTRY',
#  'C98BUSD',
#  'CELOUSDT',
#  'TRIGETH',
#  'GTOBTC',
#  'SPELLUSDT',
#  'BSWBUSD',
#  'GBPBUSD',
#  'STORJETH',
#  'SRMBUSD',
#  'STORJBUSD',
#  'POLSBUSD',
#  'PLAUSDT',
#  'DOGEPAX',
#  'SPELLBTC',
#  'ARPABUSD',
#  'XLMTUSD',
#  'AIONETH',
#  'IOTXUSDT',
#  'REEFUSDT',
#  'TWTBUSD',
#  'USDTDAI',
#  'NKNBNB',
#  'KEEPBTC',
#  'XTZBNB',
#  'RAYBUSD',
#  'COSBNB',
#  'SHIBTRY',
#  'TUSDBTUSD',
#  'RUNEUSDT',
#  'EDOETH',
#  'TFUELBTC',
#  'ARPARUB',
#  'ADABUSD',
#  'ALICEUSDT',
#  'PHBTUSD',
#  'BADGERUSDT',
#  'MBLBNB',
#  'PAXGUSDT',
#  'BCPTUSDC',
#  'PERPUSDT',
#  'FLUXBUSD',
#  'BTTBRL',
#  'WABIBTC',
#  'QSPETH',
#  'AERGOBUSD',
#  'GNOUSDT',
#  'GTOUSDC',
#  'VOXELBNB',
#  'POLYBTC',
#  'RAREBNB',
#  'DNTBUSD',
#  'ENJTRY',
#  'BULLBUSD',
#  'TUSDETH',
#  'HBARBUSD',
#  'FTTUSDT',
#  'BTCDOWNUSDT',
#  'MCBUSD',
#  'LTCBUSD',
#  'RUNEAUD',
#  'FIDAUSDT',
#  'SXPBTC',
#  'ILVBNB',
#  'SKYBTC',
#  'WINGBTC',
#  'AGIBTC',
#  'EASYBTC',
#  'API3BNB',
#  'LUNAEUR',
#  'ERNUSDT',
#  'EOSBUSD',
#  'AUDIOBUSD',
#  'BUSDTRY',
#  'UNIAUD',
#  'XRPBRL',
#  'BNTBTC',
#  'INJBNB',
#  'DEXEUSDT',
#  'DOGEBUSD',
#  'AAVEBNB',
#  'TFUELTUSD',
#  'ALGOBTC',
#  'UNFIBUSD',
#  'GTOTUSD',
#  'LUNABIDR',
#  'BNXUSDT',
#  'SUBETH',
#  'WTCETH',
#  'ATOMPAX',
#  'C98USDT',
#  'TUSDBTC',
#  'FIOBTC',
#  'MLNBUSD',
#  'ZRXBNB',
#  'AUDUSDT',
#  'MOVRBNB',
#  'PERLBNB',
#  'CHESSUSDT',
#  'RLCBUSD',
#  'GALATRY',
#  'APEAUD',
#  'CTKBTC',
#  'DOGEBTC',
#  'ANYUSDT',
#  'IOSTETH',
#  'ALICEBTC',
#  'MATICUSDT',
#  'EOSBULLBUSD',
#  'SCBTC',
#  'DCRBUSD',
#  'BNBTRY',
#  'KSMAUD',
#  'ETHUSDP',
#  'UNFIBNB',
#  'BONDBUSD',
#  'BONDUSDT',
#  'CHESSBTC',
#  'CVPUSDT',
#  'UNFIUSDT',
#  'FETBUSD',
#  'FIOBUSD',
#  'RAREUSDT',
#  'DFUSDT',
#  'MODETH',
#  'COMPBNB',
#  'XEMBNB',
#  'APPCBNB',
#  'SOLBTC',
#  'AXSBIDR',
#  'BUSDDAI',
#  'QIUSDT',
#  'BCCBTC',
#  'CITYBNB',
#  'XLMBTC',
#  'RAYBNB',
#  'XVSBTC',
#  'SKYBNB',
#  'THETABNB',
#  'POAETH',
#  'SUPERUSDT',
#  'BIFIBUSD',
#  'DGBBUSD',
#  'GRTBTC',
#  'REEFBIDR',
#  'NCASHBNB',
#  'BTTBTC',
#  'GVTBTC',
#  'KMDBTC',
#  'WANUSDT',
#  'RLCETH',
#  'BTTEUR',
#  'FTMTRY',
#  'XLMUPUSDT',
#  'XLMTRY',
#  'LTCETH',
#  'AVABUSD',
#  'COCOSBNB',
#  'EOSUSDT',
#  'GALABNB',
#  'BCPTBNB',
#  ...}
